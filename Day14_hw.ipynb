# %%
from selenium import webdriver
import time

driver = webdriver.Chrome('/Users/bokyung/Documents/mogakco/chromedriver')

login_url = 'https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com'
driver.get(login_url)

time.sleep(3)

my_id = 'leebk1124'
my_pw = 'dlqhrud-1124'

driver.execute_script("document.getElementsByName('id')[0].value = \'" + my_id + "\'")
driver.execute_script("document.getElementsByName('pw')[0].value = \'" + my_pw + "\'")

driver.find_element_by_id('log.login').click()

time.sleep(1)

comu_url = 'https://cafe.naver.com/codeuniv'
driver.get(comu_url)

time.sleep(1)

driver.find_element_by_id('menuLink90').click()

time.sleep(1)

driver.switch_to.frame('cafe_main')

time.sleep(1)

driver.find_element_by_xpath('//*[@id="main-area"]/div[4]/table/tbody/tr[1]/td[1]/div[2]/div/a').click()

time.sleep(5)

#신규회원게시판 최근 20개 게시물 내용 출력

for i in range(1, 21):
    driver.implicitly_wait(10)
    content = driver.find_element_by_css_selector('div.se-component-content').text

    print('<', i, '번째 글>\n', content, '\n')
    
    driver.find_element_by_css_selector('a.BaseButton.btn_next.BaseButton').click()
# Out:
# < 1 번째 글>
#  책추처받습니다..
#
# < 2 번째 글>
#  코딩잘하는방법좀알려주세여
#
# < 3 번째 글>
#  반갑습니다.
#
# < 4 번째 글>
#  안녕하세요 반갑습니다ㅎㅎ 잘 부탁 드리고 같이 발전해 나가요~!
#
# < 5 번째 글>
#  잘 부탁드립니다.
#
# < 6 번째 글>
#  ㅎㅇㅇ
#
# < 7 번째 글>
#  잘부탁드립니다
#
# < 8 번째 글>
#  코린이 인사드립니다 .많은도움바랍니다
#
# < 9 번째 글>
#  안녕하세요
#
# < 10 번째 글>
#  반갑습니다!!
#
# < 11 번째 글>
#  저도 어서 코린이를 벗어나 더 많이 소통하고 싶어요 ㅎㅎ
#
# < 12 번째 글>
#  21년도가 왔구나~ 코로나는 언제쯤 물러가려나~ 하고 카운트다운 봤었던게 엊그제 같은데
# 벌써 4월 5일 식목일이네요...?
# 날씨도 너무 좋고 모각코 회원님들 다들 따사로운 에너지 팍팍 받으시길 바라요!
# 건강도 조심하시고요 :-)
#
# < 13 번째 글>
#  안녕하세요 이제 파이썬을 배운지 1달도 되지 않은 초보입니다.
#
# < 14 번째 글>
#  안녕하세요
#
# < 15 번째 글>
#  반갑습니다
#
# < 16 번째 글>
#  대항생이고 파이썬 공부하고 있습니다.. 고등학교때 c언어를 1년간 독학으로 공부해서 파이썬은 크게 부담 없을 거라 생각했는데 아직 기본이 많이 부족다고 느낍니다...여기서 도움을 받을 수 있을 것 같아서 가입하게 되었습니다!. 잘 부탁 드립니다..
#
# < 17 번째 글>
#  안녕하게요 웹개발 앱개발 관심있어 가입했습니다%
#
# < 18 번째 글>
#  코린이지만 이카페에서 많은 정보를 배워가 제 실력이 많이 발전했으면 좋겠습니다ㅎㅎ!! 다들 잘 부탁드려요
#
# < 19 번째 글>
#  반갑습니다
#
# < 20 번째 글>
#  같이 힘내서 공부하면 좋을 것 같아요 ㅎㅎ
